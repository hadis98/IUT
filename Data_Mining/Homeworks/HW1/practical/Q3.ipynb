# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import plotly.express as px

# %% [markdown]
# ### Question1

# %%
houses = pd.read_csv('Housing.csv')
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### Question2
# Delete rows containing null values in this dataset

# %%
houses.dropna(inplace=True)

# %% [markdown]
# ### Question3
# For the "ocean_proximity" column, display all unique values along with the number of each value

# %%
houses["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### Question4
# Display the two characteristics of longitude and latitude on the map using location data and specify the density of the areas where there are more houses or on the map.

# %%
fig = plt.figure(figsize=(12,9))

m = Basemap(projection = 'mill', llcrnrlat = -90, urcrnrlat = 90, llcrnrlon = -180, urcrnrlon = 180, resolution = 'c')
# drawing the coastline
m.drawcoastlines()
m.drawcountries(color='gray')
m.drawstates(color='gray')

lat = houses['latitude'].tolist()
lon = houses['longitude'].tolist()
# plotting the map
m.scatter(lon, lat, latlon = True, s = 10, c = 'red', marker = 'o', alpha = 1)

plt.show()

# %%
# plotting map using plotly
plt.figure(figsize=(15,9))
fig = px.scatter_geo(houses, lat = 'latitude', lon = 'longitude')

# setting title for the map
fig.update_layout(title = 'Houses', title_x = 0.5)
# Out:
# <div>                            <div id="b8576108-406b-44a8-8fc3-9fd59757b87a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8576108-406b-44a8-8fc3-9fd59757b87a")) {                    Plotly.newPlot(                        "b8576108-406b-44a8-8fc3-9fd59757b87a",                        [{"geo":"geo","hovertemplate":"latitude=%{lat}<br>longitude=%{lon}<extra></extra>","lat":[37.88,37.86,37.85,37.85,37.85,37.85,37.84,37.84,37.84,37.84,37.85,37.85,37.85,37.84,37.85,37.85,37.85,37.85,37.84,37.84,37.85,37.85,37.84,37.84,37.84,37.85,37.85,37.85,37.84,37.84,37.84,37.84,37.84,37.83,37.83,37.83,37.83,37.83,37.83,37.83,37.83,37.83,37.84,37.84,37.83,37.83,37.83,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.82,37.83,37.82,37.81,
# ...
