# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Question1
# First, read the dataset using the pandas library and convert it into a data frame

# %%
smartphones = pd.read_csv('Smartphone.csv')
smartphones
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ### Question2
# Display the descriptive information of the dataset such as the number and type of data in each column and the volume of the dataset

# %%
smartphones.size
#total number of entities which is equal to rows*columns
# Out:
# 44000

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
smartphones.shape
#number of rows and columns of dataframe
# Out:
# (2000, 22)

# %% [markdown]
# ### Question3
# Separate and display rows of data related to phones that have the ability to connect to Bluetooth and whose internal memory size is more than 10 gigabytes.

# %%
smartphones["int_memory"]
# Out:
# 0        7
# 1       53
# 2       41
# 3       10
# 4       44
#         ..
# 1995     2
# 1996    39
# 1997    36
# 1998    46
# 1999    45
# Name: int_memory, Length: 2000, dtype: int64

# %%
has_bluetooth = smartphones["blue"] == 1
internal_memory_greater_10 = smartphones["int_memory"] > 10
smartphones[has_bluetooth & internal_memory_greater_10]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 4              1821     1          1.2         0  13       1          44
# 8              1445     1          0.5         0   0       0          53
# 11             1520     1          2.2         0   5       1          33
# ...             ...   ...          ...       ...  ..     ...         ...
# 1990           1617     1          2.4         0   8       1          36
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1996           1965     1          2.6         1   0       0          39
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ### Question4
# Extract and display the information of phones that have the strongest and weakest front camera from the dataset

# %%
#Front Camera mega pixels == fc
highest_fc = smartphones["fc"].max()
lowest_fc = smartphones["fc"].min()
has_highest_fc = smartphones["fc"] == highest_fc
has_lowest_fc = smartphones["fc"] == lowest_fc
smartphones[has_highest_fc | has_lowest_fc]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 3               615     1          2.5         0   0       0          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1971            538     0          1.1         1   0       1          25
# 1984            797     0          2.2         1   0       0          37
# 1993           1467     1          0.5         0   0       0          18
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ### Question5
# Add a new column called clock_rate to the dataset and for phones whose clock_speed is equal to or less than 1, set the value of this column to Low, for those that are greater than 1 and less than 2, set the value of this column to Mid, and for those that clock_speed is more than 2. Set the new column value to High

# %%
def set_clock_speed(clock_speed):
    if clock_speed <=1 :
        return "Low"
    elif clock_speed >1 and clock_speed <2:
        return "Mid"
    else: 
        return "High"

# %%
smartphones["clock_rate"] = smartphones["clock_speed"].apply(set_clock_speed)

# %%
smartphones
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# ### Question6
# Obtain the correlation between the different values of this dataset using a heatmap diagram and report it if there is a strong relationship between two non-target variables.

# %%
smartphones.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
sns.heatmap(smartphones.corr(),cmap="crest", annot=False)

# %% [markdown]
# ### features having correlation based on the plot
# 1. pc , fc => 0.64
# 2. price_range , ram =>  0.92
# 3. px_width,px_height => 0.51
# 4. sc_h,sc_w  => 0.51
# 5. three_g,four_g  => 0.58

# %%
plt.figure(figsize=(20,20))
sns.heatmap(smartphones.corr(),cmap="crest", annot=True)

# %% [markdown]
# ### Question7
# Display the value of the battery power column as a histogram.

# %%
smartphones["battery_power"].value_counts().plot(kind="hist")
plt.title("Battery Power Histogram")
# Out:
# Text(0.5, 1.0, 'Battery Power Histogram')
